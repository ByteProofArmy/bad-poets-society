# %% [markdown]
# ### Bad Poets Society – Poem Generator (Python)
#
# This notebook documents the development of a small poem generator for the Bad Poets Society assignment.
#
# We use three themed inspiring sets (love, nature, dream), extract word lists with spaCy,
# and then recombine them with simple templates and randomness.

# %%
# Loading libraries
import spacy
from collections import Counter
from pathlib import Path

nlp = spacy.load("en_core_web_sm")

# %%
# load the inspiring sets
from pathlib import Path

love_text = Path("poems_love.txt").read_text(encoding="utf-8")
nature_text = Path("poems_nature.txt").read_text(encoding="utf-8")
dream_text = Path("poems_dream.txt").read_text(encoding="utf-8")

# %% [markdown]
# #### Extracting themed vocabularies with spacy
#
# Here I use spaCy to process each inspiring set and extract three types of words:
#
# - nouns,
# - adjectives,
# - verbs.
#
# I keep lemmas instead of surface forms, and filter out very short or non-alphabetic
# tokens. This gives me three separate vocabularies (love, nature, dream) that define
# the style and imagery of each theme.

# %%
def extract_vocab(text: str):
    doc = nlp(text)

    nouns = set()
    adjs = set()
    verbs = set()

    for token in doc:
        if not token.is_alpha:
            continue
        lemma = token.lemma_.lower()

        # remove very short words
        if len(lemma) <= 2:
            continue

        if token.pos_ == "NOUN":
            nouns.add(lemma)
        elif token.pos_ == "ADJ":
            adjs.add(lemma)
        elif token.pos_ == "VERB":
            verbs.add(lemma)

    return sorted(nouns), sorted(adjs), sorted(verbs)

# %% [markdown]
# #### Small grammar fixes with inflection
#
# Early tests showed many subject–verb agreement errors (e.g. “someone love the tree”)
# and only singular nouns. In this part I use:
#
# - `lemminflect` to choose a 3rd person singular verb form (e.g. `someone loves`),
# - `inflect` to create plural nouns when the template asks for `N_PL`.
#
# The goal is not perfect grammar, but to reduce the most obvious errors while
# keeping the “bad poetry” flavour.

# %%
from lemminflect import getInflection
import inflect

# Initialize inflect engine for noun pluralization
inflect_engine = inflect.engine()

def inflect_verb(lemma: str, pronoun: str | None) -> str:
    """
    Do a small grammar fix on the verb form based on the subject pronoun:
    - for he / she / it / someone / no one → use 3rd person singular (VBZ)
    - for other cases (I / you / we / they / None) → keep the base lemma
    """
    if pronoun is None:
        return lemma

    lower = pronoun.lower()

    if lower in ["he", "she", "it", "someone", "no one"]:
        infl = getInflection(lemma, tag="VBZ")
        return infl[0] if infl else lemma
    return lemma


def pluralize_noun(noun: str) -> str:
    """
    Use inflect to turn a noun into its plural form.
    For example: child → children, sky → skies.
    If the conversion fails, fall back to the original word.
    """
    plural = inflect_engine.plural(noun)
    return plural if plural else noun

# %%
NOUNS_LOVE, ADJ_LOVE, VERBS_LOVE = extract_vocab(love_text)
NOUNS_NATURE, ADJ_NATURE, VERBS_NATURE = extract_vocab(nature_text)
NOUNS_DREAM, ADJ_DREAM, VERBS_DREAM = extract_vocab(dream_text)

# %% [markdown]
# #### Shared function words
#
# In addition to theme-specific vocabularies, I also define some shared word lists:
#
# - adverbs,
# - pronouns,
# - time expressions.
#
# These are used across all themes and help give the lines a bit more rhythm and
# coherence

# %%
ADVERBS = [
    "slowly", "almost", "again", "barely", "softly", "quietly", "tonight",
    "always", "forever", "never", "suddenly", "secretly", "somehow", "gently",
    "briefly", "carefully"
]

PRONOUNS = ["I", "you", "we", "no one", "someone"]

TIMES = [
    "at midnight", "before dawn", "after the last train", "on a Tuesday",
    "at closing time", "at 3 a.m.", "before the storm", "after work"
]

# %% [markdown]
# #### Cleaning the vocabularies
#
# Some words from the inspiring sets lead to outputs that are either too distracting or
# simply not useful for my generator.
# In this cell I apply small manual blacklists to remove a few nouns and verbs.
# This is a simple but important design choice: I am already shaping what my “bad poet”
# is allowed to talk about.

# %%
# filtering bad words
BAD_LOVE_NOUNS = {"crime", "bank"}  
NOUNS_LOVE = [w for w in NOUNS_LOVE if w not in BAD_LOVE_NOUNS]

BAD_NATURE_NOUNS = {"flesh"}
NOUNS_NATURE = [w for w in NOUNS_NATURE if w not in BAD_NATURE_NOUNS]

# %% [markdown]
# #### Word pools per theme
#
# This section bundles everything into a single structure: `WORD_POOLS_THEMED`.
#
# For each theme (`"love"`, `"nature"`, `"dream"`), I store the corresponding nouns,
# adjectives and verbs, plus the shared adverbs, pronouns and times.
# The rest of the generator can now work just by switching the `theme` parameter, while
# reusing the same code.

# %%
WORD_POOLS_THEMED = {
    "love": {
        "N": NOUNS_LOVE,
        "ADJ": ADJ_LOVE,
        "V": VERBS_LOVE,
        "ADV": ADVERBS,
        "PRON": PRONOUNS,
        "T": TIMES,
    },
    "nature": {
        "N": NOUNS_NATURE,
        "ADJ": ADJ_NATURE,
        "V": VERBS_NATURE,
        "ADV": ADVERBS,
        "PRON": PRONOUNS,
        "T": TIMES,
    },
    "dream": {
        "N": NOUNS_DREAM,
        "ADJ": ADJ_DREAM,
        "V": VERBS_DREAM,
        "ADV": ADVERBS,
        "PRON": PRONOUNS,
        "T": TIMES,
    },
}

# %% [markdown]
# #### Line templates
#
# Here I define a small set of line templates.

# %%
LINE_PATTERNS = [
    ["PRON", "V", "the", "ADJ", "N"],          # I touch the silent night
    ["in", "the", "ADJ", "N"],                # in the bright field
    ["beneath", "the", "ADJ", "N"],           # beneath the yellow breeze
    ["sometimes", "PRON", "V", "the", "N"],   # sometimes we hold the dream
    ["PRON", "V", "N", "T"],                  # I follow dream at midnight
    ["in", "the", "ADJ", "N", "PRON", "V", "N", "T"], 
    ["the", "ADJ", "N", "V", "ADV"],          # the subtle road fade slowly
]

# %%
import random

def generate_line(theme: str = "love") -> str:
    """
    Generate a single line of poetry for a given theme.

    Logic:
    - Randomly select a pattern from LINE_PATTERNS.
    - Lowercase tokens (in, the, beneath, ...) are used as literal words.
    - Uppercase tokens are interpreted as placeholders:
        - PRON: sample a pronoun from the theme's PRON list and remember it
        - V:    sample a verb lemma from V, then inflect it based on the current pronoun
        - N:    sample a singular noun
        - N_PL: sample a noun and convert it to its plural form using inflect
    """
    if theme not in WORD_POOLS_THEMED:
        raise ValueError(
            f"Unknown theme: {theme}. Available themes: {list(WORD_POOLS_THEMED.keys())}"
        )

    pools = WORD_POOLS_THEMED[theme]
    pattern = random.choice(LINE_PATTERNS)

    words: list[str] = []
    current_pronoun: str | None = None

    for token in pattern:
        if token.islower():
            # Fixed lowercase word
            words.append(token)
        elif token == "PRON":
            pron = random.choice(pools["PRON"])
            current_pronoun = pron
            words.append(pron)
        elif token == "V":
            verb_lemma = random.choice(pools["V"])
            verb_form = inflect_verb(verb_lemma, current_pronoun)
            words.append(verb_form)
        elif token == "N_PL":
            noun_lemma = random.choice(pools["N"])
            noun_form = pluralize_noun(noun_lemma)
            words.append(noun_form)
        elif token == "N":
            noun_lemma = random.choice(pools["N"])
            words.append(noun_lemma)
        else:
            # Other tags, such as ADJ, ADV, T (time expressions)
            words.append(random.choice(pools[token]))

    line = " ".join(words)
    return line[0].upper() + line[1:]

# %%
def generate_title(theme: str = "love") -> str:
    pools = WORD_POOLS_THEMED[theme]
    adj = random.choice(pools["ADJ"]).capitalize()
    noun = random.choice(pools["N"])
    return f"{adj} {noun}"

# %%
def generate_poem(
    theme: str = "love",
    min_lines: int = 6,
    max_lines: int = 10,
    with_title: bool = True,
    seed: int | None = None,
) -> str:
    if theme not in WORD_POOLS_THEMED:
        raise ValueError(f"Unknown theme: {theme}. Use 'love' or 'nature'.")

    if seed is not None:
        random.seed(seed)

    num_lines = random.randint(min_lines, max_lines)
    lines = [generate_line(theme=theme) for _ in range(num_lines)]

    if with_title:
        title = generate_title(theme=theme)
        poem_str = title + "\n" + "-" * len(title) + "\n" + "\n".join(lines)
    else:
        poem_str = "\n".join(lines)

    return poem_str

# %%
print("=== DREAM THEME ===\n")
for i in range(10):
    print(generate_poem(theme="dream"))
# Out:
# === DREAM THEME ===
#
# Happy nightmare
# ---------------
# In the true heart
# The dangerous house continue forever
# In the cloudy dust
# Sometimes no one fatigues the leisure
# We subdue willow after work
# Someone prevails the hard scenery
# In the fresh breaks someone shocks space before dawn
# The clear grave hate slowly
# You achieve scalp after the last train
# Right end
# ---------
# Beneath the good spring
# Sometimes we waste the pond
# You collide melody at midnight
# You process the unfamiliar tree
# You walk the well darkness
# The smart angel come carefully
# Someone steps the wonderful opportunity
# Very desire
# -----------
# The firm creation wound barely
# Sometimes you bless the bed
# In the unreal harbinger
# Sometimes you reign the infinity
# The blank fulfilled perceive slowly
# No one freezes vacuum at 3 a.m.
# Ready kid
# ---------
# Beneath the well mockup
# In the hungry clock
# Sometimes no one bleeds the grave
# Sometimes we survive the suffering
# Sometimes no one bears the ecstasy
# Sometimes someone rises the focus
# In the dribble shore
# In the insane forest no one happens car before the storm
# Sometimes I create the flesh
# Beneath the near succulent
# Alone heart
# -----------
# Sometimes I hug the pulse
# No one prepares the alone fall
# The warm tonight fail gently
# Sometimes I wish the roar
# In the warm snake someone rejects direction on a Tuesday
# Sometimes I fail the compassion
# No one collects breath before dawn
# In the warm dreaming
# Conscious create
# ----------------
# In the well eye no one gleams fantasy at 3 a.m.
# The blank bed whimper slowly
# In the underwater shadow you live thunder after the last train
# You search the unbroken artery
# In the near hardship
# The cold pool prepare forever
# You stop return after work
# American child
# --------------
# Sometimes we listen the dignity
# No one connects the alone energy
# No one takes the loud noise
# In the open goal
# In the barren choice I pray dead before the storm
# Beneath the bright forest
# I dwell the profound illusion
# In the hard degree someone tears feeling before dawn
# Dry body
# --------
# In the erect death no one traps sincerity on a Tuesday
# You fly height on a Tuesday
# I work the selfish evil
# In the accurate wall
# Beneath the free puzzle
# In the great friendship someone seeks woman before dawn
# Sometimes we find the squeal
# Beneath the illusory spring
# The hungry wanderer hoot never
# Cold moonlight
# --------------
# No one hides the near wall
# No one survives the busy skin
# In the smart stride we burn wall after work
# Sometimes someone flowers the room
# Beneath the future jaw
# Sometimes you subdue the midst
# The about pow take slowly
# Sometimes no one pulls the poem
# In the hazy eyes
# You blaze disappear after work
# Stray order
# -----------
# In the real light
# Someone resents degree before the storm
# We control cook after work
# In the profound signal we laugh pace after work
# Beneath the stray home
# No one owns train at midnight
# The hungry willow notice again
# You forget the insane hardship

# %%
print("=== LOVE THEME ===\n")
for i in range(10):
    print(generate_poem(theme="love"))

print("\n=== NATURE THEME ===\n")
for i in range(10):
    print(generate_poem(theme="nature"))
# Out:
# === LOVE THEME ===
#
# Lonely dinosaur
# ---------------
# In the cheerful grief
# Sometimes someone pays the spear
# In the mindful really
# In the deafening system no one instructs list at 3 a.m.
# The menacing shield समझ almost
# In the beloved king
# Sometimes you speak the spirit
# I swell home on a Tuesday
# The tough mai dance always
# Beneath the careless fray
# Permanent well
# --------------
# In the barren thunder no one needs girl after the last train
# In the real coating
# In the about song we practice compliment after work
# In the lonely reply you widen shareholder before the storm
# Beneath the easy cry
# In the unknown happiness
# The valuable dong come briefly
# Sometimes you base the madness
# Someone requires the strange hunger
# Inevitable truce
# ----------------
# You send arm on a Tuesday
# In the only abbie
# You thrive the amusing cry
# You suppress the charming thing
# Someone admits the regretful stage
# I hide work before the storm
# In the mere business we light ranger before dawn
# In the heavenly breeze
# Beneath the indecisive stage
# We flow the grand thorn
# Imperious trial
# ---------------
# Sometimes no one peppers the embrace
# Beneath the regretful haystack
# I want freak at midnight
# Beneath the fantastic breath
# Sometimes someone dosts the bed
# Beneath the unfelt state
# The unquenchable daffodil ooze again
# Someone betrays instrument after work
# We build reply before dawn
# In the mindful rip
# Pure rose
# ---------
# Sometimes someone cheats the name
# We wait the same coast
# Sometimes we begin the bill
# We accompany the live boundary
# Beneath the bent mercy
# In the fine struggle I fit fate at midnight
# Permanent rip
# -------------
# Sometimes someone blossoms the affirmation
# In the selfish grace you look member at closing time
# In the sweet state
# In the valuable shore
# Beneath the crumb door
# In the absurd word
# Sometimes we invite the bed
# Someone whispers the memorable topaz
# Sometimes I mind the solitude
# Bumpy sky
# ---------
# In the free dawn we suppress jodi before dawn
# Sometimes we convey the kid
# I understand the live ghost
# In the beloved cheek we hope bunny at 3 a.m.
# No one affects shore at 3 a.m.
# Sometimes someone swims the fret
# Beneath the litany belief
# Beneath the slow kab
# Sometimes you hold the phrase
# Scarlet bridge
# --------------
# Sometimes no one breeds the flood
# Someone dosts daffodil after work
# No one knocks the black hither
# We suppress mile on a Tuesday
# In the okay poof
# In the deafening plunge
# I lock the long laughter
# Beneath the scarlet issue
# In the profound territory I attend force at midnight
# You forget the enough firmament
# Unbearable human
# ----------------
# Sometimes no one marries the bar
# In the precise rip we envy needle before the storm
# I offer dog before dawn
# Beneath the selfish arch
# In the white desk
# I break naught on a Tuesday
# I blossom the foolish pair
# True coast
# ----------
# We fly ash at 3 a.m.
# The aqueous daydream linger somehow
# Sometimes no one conveys the power
# Beneath the ding kab
# Sometimes we ooze the cry
# The free church sway softly
#
# === NATURE THEME ===
#
# Shiny peak
# ----------
# The low wonder speak always
# Someone pleases the intricate tree
# Sometimes no one blows the city
# The little morning disappear briefly
# Sometimes I greet the pain
# We shake solace at midnight
# Sometimes someone plagues the wound
# The wise orchid help quietly
# In the reluctant lightning you appear flutter at closing time
# Different alight
# ----------------
# Beneath the unaware reason
# I muddy the infinite deceit
# Someone sheds the grey breakfast
# The privy brim settle barely
# Beneath the tranquil rest
# The gentle day light barely
# We carpet house after work
# In the young bear we walk mercy after the last train
# In the sure mountain
# Infinite water
# --------------
# Someone smooths the heavenly tulip
# The rustle transcend deal secretly
# Someone holds the good fire
# Someone covers ecstasy at 3 a.m.
# In the tall bubble
# In the most softness
# We know the confused creature
# No one wakes nature after the last train
# The frozen gill reveal forever
# Cool choir
# ----------
# In the colorless awakening
# We grace the open petal
# The endless sapphire evoke carefully
# The colored store step suddenly
# The orange cry confront almost
# The most tide keep secretly
# The unique flitter achieve forever
# Great loon
# ----------
# Beneath the mutable door
# Sometimes we create the breath
# Sometimes someone ends the fruit
# Sometimes no one meets the depth
# The soft exploitative spark suddenly
# In the grateful east no one sings cycle before the storm
# Someone strikes the mutable foot
# Beneath the unique airy
# Earthy airy
# -----------
# Beneath the tender west
# In the different ecstasy
# Someone murmurs aught on a Tuesday
# Sometimes someone blows the wood
# Beneath the bright sister
# In the kind fin someone takes side before dawn
# Beneath the hive bookkeeper
# Sometimes no one cuddles the ease
# Legged eambiance
# ----------------
# You experiment the near ear
# The vaunted bolder notice always
# Sometimes no one plants the fin
# In the near sheet we aspire music at 3 a.m.
# The other blossom get secretly
# The refreshing look spend somehow
# Sometimes someone waters the man
# In the privy beach
# The kind duckling destroy carefully
# Nice control
# ------------
# Beneath the prakriti serenity
# In the fond seed
# In the wondrous sprite someone plots lord on a Tuesday
# In the tranquil prance
# Sometimes we hide the whisper
# Someone darkens the green marvel
# In the little visual I stop mid before dawn
# Someone ranges bear at closing time
# In the frightening excitement I set sadness before dawn
# The vibrant moon hold suddenly
# Strong moss
# -----------
# The cheerful evening give secretly
# In the such patch I think universe at midnight
# Sometimes no one restores the nature
# In the curious tranquil you see spix on a Tuesday
# In the fruitful horizon someone rustles star at 3 a.m.
# No one rescinds the dim sanity
# In the familiar bloom I shin laughter at 3 a.m.
# No one puts delight at closing time
# Beneath the joyful laughter
# Pretty illusion
# ---------------
# In the same food
# Sometimes someone clothes the wound
# In the short money
# No one sounds bed after work
# No one smooths the true flow
# In the splendid bird someone evokes room on a Tuesday

# %% [markdown]
# #### Reflecting on creativity
#
# In this project, my poem generator combines themed vocabularies (love, nature, dream),
# a small set of line templates, controlled randomness, and light grammatical inflection.
# To think about the creativity of such a system, I focused on three aspects:
#
# - **Novelty** – whether the system keeps producing new and surprising combinations of
#   words across different runs.
# - **Thematic consistency** – whether poems generated under different themes actually
#   differ in mood, imagery and atmosphere.
# - **Aesthetic interest** – whether some lines or images feel evocative, ironic or
#   memorable enough to be worth keeping or presenting.
#
# My evaluation was qualitative rather than numerical. I generated many poems, read
# through them, and manually selected a small number of favourites for each theme
# (these are recorded in `the3_for_ai.txt`). These selected poems were then used as
# the basis for image and audio generation, which often amplified their perceived
# meaning and emotional tone.
